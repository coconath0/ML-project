# %%
import openml
import pandas as pd

# List available datasets
openml_list = openml.datasets.list_datasets()
datalist = pd.DataFrame.from_dict(openml_list, orient="index")
print(datalist.head()) # View the first few datasets

# %%
# Load a dataset by ID (e.g., Water quality dataset ID is 46085)
dataset = openml.datasets.get_dataset(46085)

# Or, load by name and version
# dataset = openml.datasets.get_dataset('Water_Quality', version=1)
